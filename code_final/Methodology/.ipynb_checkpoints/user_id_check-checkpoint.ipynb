# %%
import pandas as pd
import tweepy
from importlib.machinery import SourceFileLoader
twitter_credentials = SourceFileLoader("twitter_credentials.py", "/Users/dorianbenutzer/Desktop/Digital_Twitter_Layer/Scripts/Twitter_scrapper/twitter_credentials.py").load_module()

from tweepy import API
from tweepy import Cursor
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import time
import sys
import csv

csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
class TwitterAuthenticator():
    def authenticate_twitter_app(self):
        auth = OAuthHandler(twitter_credentials.CONSUMER_KEY,twitter_credentials.CONSUMER_SECRET)
        auth.set_access_token(twitter_credentials.ACCESS_TOKEN, twitter_credentials.ACCESS_TOKEN_SECRET)
        return auth

# %%
data = pd.read_csv('/Users/dorianbenutzer/Desktop/Digital_Twitter_Layer_local/data/Jan/software_firms_with_best_urls_and_twitter.csv', sep="\t", engine='python')

# %%
# have twitter handle and confidence>0
twitter_handle = data[data.twitter.notnull()]
twitter_handle_conf = twitter_handle[twitter_handle['confidence'] > 0]
twitter_handle_conf
# Out:
#               ABI                  dl_slot error  confidence  \
# 17      998836456         swiftsystems.com  None        0.95
# 18      998834196                neted.org  None        0.50
# 20      998823546        mediatechplus.com  None        0.60
# 23      998814818          systemtools.com  None        0.45
# 24      998795991  quickpro-consulting.com  None        0.50
# ...           ...                      ...   ...         ...
# 112634    2284941              geneseo.com  None        0.05
# 112645    1615608                 caci.com  None        0.50
# 112647    1500438                  ctg.com  None        0.50
# 112650     884007           windstream.com  None        0.50
# 112652     592444             agilysys.com  None        0.50
#
#                                                     links           twitter
# 17      a2la.org,wrightmfg.com,amsvendors.com,cityoffr...  @SwiftSystemsInc
# 18      netcaucus.org,ilpfoundry.us,stateofthenet.org,...       @netedfound
# ...

# %%
auth = TwitterAuthenticator().authenticate_twitter_app()
twitter_client = API(auth, wait_on_rate_limit = True, wait_on_rate_limit_notify = True)

# %%
twitter = ['@Intratech_IT',
 '@BeverDigital',
 '@MicroTech_Boise',
 '@TecoloteInc',
 '@usvisnet',
 '@Applieddatatech',
 '@pasafety2',
 '@ItMerkem',
 '@swipsystems',
 '@AmtexBI',
 '@KologikData',
 '@legal_files',
 '@inc_simplified',
 '@ADigiSolution',
 '@indico_co',
 '@PersystEEG',
 '@eitct',
 '@unitedpcsupport',
 '@RehmTechDotCom',
 '@ServicesDna',
 '@nuvancehealth',
 '@drillinginfo',
 '@sparrow_systems',
 '@NetZoomInc',
 '@amphioncomm1',
 '@HealthDiligent',
 '@goodcoworkingtx',
 '@Catalyst_ITnet',
 '@rx_technology',
 '@RBACInc',
 '@Asoftwoods',
 '@NeoTekEntInc',
 '@3c_CoasttoCoast',
 '@the_asci',
 '@MLGC_Griggs',
 '@PCCreativeServ',
 '@mcc_servicing',
 '@sublimedzine',
 '@AssaiWebDesign',
 '@WhoTracks_me',
 '@hulagirlweb',
 '@GotIt_AI',
 '@themaxeemize',
 '@twitter',
 '@SummitTech360',
 '@1upseo',
 '@Encrypgen',
 '@popdart1',
 '@rms_automotive',
 '@FollowItps',
 '@byredtree',
 '@thespadedesign',
 '@cardinaltechno1',
 '@i3mediasolution',
 '@livinginave',
 '@emonics_llc',
 '@ctrisenetwork',
 '@YewnoFinance',
 '@EclipsosCorp',
 '@expediencesoft1',
 '@Gebni_NYC',
 '@alphafusiondigi',
 '@austeretech',
 '@celentialai',
 '@spider_BTB',
 '@kingsburgmedia',
 '@CendynOvations',
 '@PalmBeachBeat',
 '@intelliswiftS',
 '@DeepMapInc',
 '@ACAWise',
 '@EMC__solutions',
 '@utdatarecovery',
 '@BryantDigitalVB',
 '@Vector_Tech_Sys',
 '@industrial_sw',
 '@DynamicPDF',
 '@SocialSolutions',
 '@WebSEOLocal',
 '@heartoftexasit',
 '@PowePageSeo',
 '@EES_Corp',
 '@imedsoftware',
 '@ribboncomm',
 '@BuyBackPros',
 '@HarmonyTechInc',
 '@thomasroneyllc',
 '@BioTelInc',
 '@celestwebdesigr',
 '@Prime_TSR',
 '@StartupSceneME',
 '@cvo_website',
 '@akanaapi',
 '@gssglobalsoft',
 '@eplexityllc',
 '@ICES60738420',
 '@SchweersTech',
 '@EDI_Arora',
 '@DocuDriven',
 '@FriedmanHR',
 '@Opportunities_U',
 '@advancedisp',
 '@AlveoTech',
 '@TheMILCorp',
 '@sapientinsights',
 '@BizIntSmartChts',
 '@HRScreeningInc',
 '@NexantECA',
 '@DSI_TECH',
 '@QIFLLC',
 '@group_she',
 '@IVI_Ventilation',
 '@teal_tech',
 '@brentech_inc',
 '@CareStackSystem',
 '@fabretechnology',
 '@water_lantern',
 '@DCS_Indiana',
 '@TMC2Tech',
 '@KSoftSystemsInc',
 '@digitalaisw',
 '@JIVA_InfoTech',
 '@SystemsAgj',
 '@deptfordschools',
 '@PronixInc',
 '@Digitalsoftwar6',
 '@jnjmeddevices',
 '@SmartHomesSO',
 '@trilogyhealthmd',
 '@HarrisExcelergy',
 '@xplm_com',
 '@DynanetCorp',
 '@Vertexvis',
 '@rldatix',
 '@Expert_System',
 '@GoodStewardCo',
 '@AerogilityLtd',
 '@SkyMinderCRIF',
 '@Synergy_App',
 '@m2systemscorp',
 '@COVECTRA1',
 '@heartvista',
 '@valorglobalus',
 '@LionsGateTech',
 '@LarryOMillerWe1',
 '@CircleCityDigtl',
 '@AXIS_Capital',
 '@COSparkFire',
 '@sidestreet_arts',
 '@kauligmedia',
 '@CoolRunningSoft',
 '@UsSpars',
 '@intercotrading',
 '@NSGroupLLC',
 '@RITHealthcare',
 '@1eightydesign',
 '@DealerProfit',
 '@facebook',
 '@iTivityinfo',
 '@TechgroupNet',
 '@bwsoftware',
 '@KiboWorks',
 '@TTSGinc',
 '@HymarkSolutions',
 '@BuschTechSolLLC',
 '@WebHostingLog',
 '@ExymEHR',
 '@GrizzlyPeak_',
 '@FothionInc',
 '@homesafetyguide',
 '@3rpSolutions',
 '@robertharden',
 '@tksinc3',
 '@all_asset_rec',
 '@KBM_INC',
 '@sculptgroup',
 '@seofranklintn',
 '@myeleveo',
 '@scaleflux',
 '@spectrumcreinc',
 '@OnSolve',
 '@ApprGenieCloud',
 '@Ewave6',
 '@CGI_USFederal',
 '@halolabsinc',
 '@akinsit_inc',
 '@AlarmPointe',
 '@AccQdataFlorida',
 '@tranquilblue',
 '@scaleworkspace',
 '@zkw',
 '@Five_Cedars',
 '@SmartBoxDental',
 '@Lanspeed_IT',
 '@corner_sol',
 '@Tensor_IT',
 '@gogreengeeks',
 '@GroupKmetz',
 '@fusionsolution5',
 '@BusinessMariner',
 '@TechSolNet',
 '@PrBusiness1',
 '@CaretechGrp',
 '@OfSriven',
 '@venturesoftgbl',
 '@WebWhatcom',
 '@MacedonTech',
 '@chkamerica',
 '@FindYourCrux',
 '@reddragontechno',
 '@albright_ideas',
 '@astforgetech',
 '@gvillewebdesign',
 '@Remarkablehlth',
 '@themepunch',
 '@think_systems',
 '@glory_dach',
 '@group_siesta',
 '@PacwestSoftware',
 '@uscolist_com',
 '@DsSlapshot',
 '@TechnologyTulsa',
 '@ntirety',
 '@24by7liveIT',
 '@ASRGroupCareers',
 '@mind_sync',
 '@IBCMerchants',
 '@OlympicMedical',
 '@goVirtualOffic1',
 '@lubbockwebguy',
 '@macrotechCO',
 '@computerclue',
 '@Reconext_',
 '@goblackfoot',
 '@taplogic',
 '@MayorAQD',
 '@DragonflyDigit1',
 '@compu_gain',
 '@NCI1993',
 '@dinoroarvalley',
 '@crispincorp',
 '@M1Software',
 '@Precise_ST',
 '@LeacoBroadband',
 '@digitalimpactan',
 '@PointSharePlus',
 '@AssociatesRad',
 '@Logybytestexas',
 '@SaranshInc',
 '@Systech_USA',
 '@LiquidMediaIR',
 '@srivensystems',
 '@CAESolutionsUS',
 '@D_Resolve',
 '@MirageInksLtd',
 '@STSIntVA',
 '@ebusiness_intl',
 '@ipsecureinc',
 '@SoilTechGolf',
 '@_warrensystems',
 '@TProductions_UK',
 '@BiT_DMS',
 '@ALTAIT2',
 '@SynergyITServcs',
 '@tastemakersAPT',
 '@LSMedia_Digital',
 '@infomatics_tech',
 '@eXsuperoLLC',
 '@PDInvestigate',
 '@new_worlddesign',
 '@mOdcat_design',
 '@cts_kc',
 '@ITFocusLLC',
 '@13BelowConsult',
 '@T_P_Group',
 '@SKYTelecomWy',
 '@Hosturly',
 '@ISECBuilt',
 '@ALLEdesignsllc',
 '@skyfiberi',
 '@govatc',
 '@techcesscyber',
 '@TCSNapa',
 '@techstar_group',
 '@agavepay',
 '@LiendataUSA',
 '@lunadottech',
 '@engagevc',
 '@codeworkssc',
 '@ironbowhc',
 '@skylinesoft3D',
 '@CriterionCyber',
 '@MARTZTechnolog1',
 '@Blue_Sky_Evo',
 '@device_iq',
 '@PDSConsults',
 '@TecMastersInc',
 '@CrimesoftS',
 '@visualmagnetics',
 '@autotask',
 '@StarAssetSec',
 '@e_Emphasys',
 '@GeeksPara',
 '@GammaTechNaples',
 '@cloudfoundtion',
 '@OLISystems',
 '@customerbloomnj',
 '@Landscape48451',
 '@excelify_io',
 '@TrendHRRockwall',
 '@fintelnetwork',
 '@HeitzDigital',
 '@PHNSolutionsINC',
 '@TrueMVSPets',
 '@Bitechinc',
 '@youriconicit',
 '@bbhnow',
 '@AxiansInc',
 '@cumulus_systems',
 '@exelatech',
 '@versiant_msp',
 '@agdatainsights',
 '@Madwire',
 '@nciphersecurity',
 '@followTPEG',
 '@HarrisCoJudge',
 '@DataTrans_EDI',
 '@techgsmsolution',
 '@rd_design_team',
 '@_Intellinetics',
 '@thecorio',
 '@ClineLumber',
 '@Delontiinc',
 '@NetConnectNYC',
 '@TheSmartSocialM',
 '@SolutionsCdi',
 '@guardianrecnet',
 '@surgeryassocpa',
 '@strateoslab',
 '@BarracudaSkill',
 '@shelterbluetech',
 '@cspiaurora',
 '@Tech_Portal_WA',
 '@phillipcomputer',
 '@ResonateNetwrk',
 '@Scantron',
 '@modernlogicapps',
 '@HamiltonandA',
 '@bioblox1',
 '@IndigoITllc',
 '@ssasoft_llc',
 '@usigroups',
 '@GlobalEagle',
 '@cloudmailstore ',
 '@AtsTech',
 '@full_circlem',
 '@fantaitsathing',
 '@HTA_Pulse',
 '@ILoveValenciaES',
 '@GeneralStorePOS',
 '@AskConsultingId',
 '@BIPTrack',
 '@IncSimplicity',
 '@empowerprof',
 '@Xponance',
 '@vidboxinc',
 '@eschooldata',
 '@Super_Controls',
 '@BinarysoftL',
 '@Sentry_Global',
 '@appliedmfgtech',
 '@avatarmsp',
 '@onlinescraptool',
 '@catechusa',
 '@MuzeumGroup',
 '@FutureSoftIT3',
 '@milestonegroup',
 '@FisherSandler',
 '@pivotts',
 '@CyberbizS',
 '@Yoobly',
 '@GLMXTech',
 '@big_purple_dot',
 '@Logimax1',
 '@BrytechI',
 '@webcousa',
 '@ads_advantedge',
 '@AccuSpeechMobil',
 '@protelo',
 '@dynasigncorp',
 '@Element_Updates',
 '@BringCom1',
 '@DoD_HPCMP',
 '@RSI_CMS',
 '@Leorearlylearn',
 '@trunet_inc',
 '@cirium',
 '@infotechcore',
 '@PDSBiotech',
 '@locallighthouse',
 '@DigiconRocks',
 '@MitechServices',
 '@MyPulsems',
 '@RLJDevelopment',
 '@inventive_ltd',
 '@HalsteadLaw',
 '@mdcentric',
 '@BlackhawkMES',
 '@SKCGamesStudio',
 '@nappaneeindiana',
 '@bpshaw23',
 '@MBGSolutionsInc',
 '@SextonCoLaw',
 '@ITC_Comm',
 '@HourglassESC',
 '@biz_tech',
 '@ISTIncOfficial',
 '@gamssoftware',
 '@envisionFS',
 '@egrovecorp',
 '@webdesignbymwd',
 '@posPROstore',
 '@FluxLightInc',
 '@vitessesolution',
 '@MichiganSEOPro',
 '@thewynnnetwork',
 '@tributarysystem',
 '@optihq',
 '@normalmodes',
 '@VeriCorp1',
 '@FlowGuard_ME',
 '@InlandSoftware',
 '@adeptussolution',
 '@jmcgloballlc',
 '@upinholdings',
 '@NXTSTPSOLNS',
 '@currenthometec1',
 '@DawnKubiePhoto',
 '@SolutionsCit',
 '@JustVisionIt1',
 '@CherokeeFederal',
 '@RiteprosincC',
 '@techwizardsinc_',
 '@Chase_Corp',
 '@BlackhawkDsp',
 '@CelticSystem',
 '@Flexim_Americas',
 '@Eliteinteractiv',
 '@cgs_infotech',
 '@hybridps',
 '@persimmonyinc',
 '@laserbeamsoft',
 '@VeritasDNA',
 '@ilernetworking',
 '@TSI_HSV',
 '@QwikFile',
 '@CompuStrategies',
 '@UniProFoods',
 '@ItechInnovative',
 '@silicon_east',
 '@StonehengeStaff',
 '@tpg_management',
 '@vabbnet',
 '@ChiFaucetShoppe',
 '@PasqualiConsult',
 '@youviewbusiness',
 '@buyboxes',
 '@VistagraphicsI',
 '@NoelRWilliamsMD',
 '@terrostarim',
 '@IndiumSoftware',
 '@kiwiplanglobal',
 '@CloudCover2',
 '@GenesisGlobal2',
 '@UNGITsc',
 '@dnet_t',
 '@3coresystemsinc',
 '@ingenuxcom',
 '@ProtelligentIT',
 '@hypergiant',
 '@KorTerra_Inc',
 '@craftcomm',
 '@True_BlueTech',
 '@wrightbiztech',
 '@soundscapeshow',
 '@InnovativeExch1',
 '@AxusTechLLC',
 '@NOAH_AMS',
 '@FASCORWMS',
 '@Bridgewareinc',
 '@HelpdeskCompany',
 '@rapiditinc',
 '@lakesitenet',
 '@PDS_MED',
 '@CiaSoftware',
 '@NGTech5',
 '@CamperBailey',
 '@api_technology',
 '@tbsfurniture',
 '@yyesoftware',
 '@mindcore_IT',
 '@pqview ',
 '@hawaii_vacation',
 '@ciservicesllc',
 '@Rem0teit',
 '@SMS_Datacenter',
 '@industrialfx',
 '@VoxcomUK',
 '@highpoint',
 '@PleXusComm',
 '@springcharts1',
 '@yourMoveHQ',
 '@PortativeTech',
 '@myeblox',
 '@SolidusTS',
 '@amaInc62',
 '@QuadtecSol',
 '@Vijay_Soft',
 '@megadistchicago',
 '@NVRedge',
 '@dc_webpro',
 '@Bezlio',
 '@HorusVision',
 '@Inovision_Inc',
 '@accumeninc',
 '@pcudi',
 '@zelcash',
 '@4IdahoWebpages',
 '@Official_DCI',
 '@amesconstrn',
 '@imagesintegrity',
 '@AxisTechnology2',
 '@PNW_WoW',
 '@Omega_Mgmt_MN',
 '@mitinet_library',
 '@BiTechEnt',
 '@raytheondefense',
 '@kidneysoftware',
 '@DSI_Intl']

# %%
user_ids = []
users=[]
counter = 0
exceptions = []
for t in twitter:
    counter +=1
    try:
        user = twitter_client.get_user(t)
        users.append(user)
        user_ids.append(user.id)
    except Exception as e:
        exceptions.append((counter,e))

# %%
len(exceptions)
# Out:
# 16

# %%
len(users)
user_ids2 = []
for us in user:
    screen_name = us.screen_name
    
# It was correct the first time :)
# Out:
# 523

# %%
users[0].screen_name
# Out:
# 'Intratech_IT'

# %%
# get user ids


user_ids = []
user_id_not_found = []
start = time.time()
start_unaltered = time.time()
already_checked_users = []
counter = 0


for handle in twitter_handle_conf.twitter:
    counter += 1
    #ä
    dds
    
    
    try: 
        if handle not in already_checked_users:
            user = twitter_client.get_user(handle).id
            user_ids.append(user)
            already_checked_users.append(handle)
    except:
        user_id_not_found.append(handle)
        print('Exception')
    if (time.time()-start) > 120:
        print('Time since start: ', time.time()-start_unaltered)
        print(counter)
        start = time.time()

end = time.time()



print('It took %d seconds'%((end-start_unaltered)))#16320 seconds
